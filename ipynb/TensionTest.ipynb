# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
#%matplotlib notebook
# %autosave 0
    
import logging
logging.basicConfig(format='%(asctime)s %(levelname)s:%(message)s', level=logging.DEBUG, datefmt='%I:%M:%S')

import sdata
import sdata_experiments
from sdata_experiments import TestProgram
from sdata_experiments.tension_test import TensionTest, TensionTestSeries
# Out:
# 03:56:05 INFO:NumExpr defaulting to 8 threads.
# Autosave disabled
# 03:56:05 DEBUG:backend module://matplotlib_inline.backend_inline version unknown

# %%
tp_name = "TP AW-6016"
tp = TestProgram(name=tp_name, uuid=sdata.uuid_from_str(tp_name))
tp.udf
tp
# Out:
# (TestProgram 'TP AW-6016':9ccc38ef1418390b98d65ca03c963be5)

# %%
ts_name = "UT90"
ts = tp.gen_testseries(name=ts_name, uuid=sdata.uuid_from_str(ts_name), class_name=TensionTestSeries)
ts
# Out:
# (TensionTestSeries 'UT90':6a0af14426c63513ae3b3256f4148244)

# %%
t_name = "n1"
t = ts.gen_test(name=t_name, uuid=sdata.uuid_from_str(t_name), class_name=TensionTest)
t
# Out:
# (TensionTest 'n1':ba66307cd2553419ada834183831bdab)

# %%
ts.longname, t.longname
# Out:
# ('TP AW-6016|UT90', 'TP AW-6016|UT90|n1')

# %%
t.udf
# Out:
#                                                         name value unit  \
# key
# actual_gauge_length                      actual_gauge_length   NaN    -
# actual_pre_deformation                actual_pre_deformation   NaN    -
# actual_specimen_cross_section  actual_specimen_cross_section   NaN   mm
# actual_specimen_diameter            actual_specimen_diameter   NaN   mm
# actual_specimen_huminity            actual_specimen_huminity   NaN   mm
# actual_specimen_length                actual_specimen_length   NaN   mm
# actual_specimen_temperature      actual_specimen_temperature   NaN   mm
# actual_specimen_thickness          actual_specimen_thickness   NaN   mm
# actual_specimen_width                  actual_specimen_width   NaN   mm
# actual_strain_rate                        actual_strain_rate   NaN    -
# actual_testing_speed                    actual_testing_speed   NaN    -
# actual_testing_temperature        actual_testing_temperature   NaN    -
# ...

# %%
ts.udf
# Out:
#                                                                 name value  \
# key
# material_name                                          material_name
# material_norm_name                                material_norm_name
# material_number_norm                            material_number_norm
# nominal_gauge_length                            nominal_gauge_length   NaN
# nominal_pre_deformation                      nominal_pre_deformation   NaN
# nominal_pre_deformation_direction  nominal_pre_deformation_direction
# nominal_specimen_cross_section        nominal_specimen_cross_section   NaN
# nominal_specimen_diameter                  nominal_specimen_diameter   NaN
# nominal_specimen_huminity                  nominal_specimen_huminity   NaN
# nominal_specimen_length                      nominal_specimen_length   NaN
# nominal_specimen_temperature            nominal_specimen_temperature   NaN
# nominal_specimen_thickness                nominal_specimen_thickness   NaN
# ...

# %%
t.udf
# Out:
#                                                         name value unit  \
# key
# actual_gauge_length                      actual_gauge_length   NaN    -
# actual_pre_deformation                actual_pre_deformation   NaN    -
# actual_specimen_cross_section  actual_specimen_cross_section   NaN   mm
# actual_specimen_diameter            actual_specimen_diameter   NaN   mm
# actual_specimen_huminity            actual_specimen_huminity   NaN   mm
# actual_specimen_length                actual_specimen_length   NaN   mm
# actual_specimen_temperature      actual_specimen_temperature   NaN   mm
# actual_specimen_thickness          actual_specimen_thickness   NaN   mm
# actual_specimen_width                  actual_specimen_width   NaN   mm
# actual_strain_rate                        actual_strain_rate   NaN    -
# actual_testing_speed                    actual_testing_speed   NaN    -
# actual_testing_temperature        actual_testing_temperature   NaN    -
# ...

# %%
ts.sname
# Out:
# 'TensionTestSeries|UT90|6a0af14426c63513ae3b3256f4148244'

# %%
ts.name
# Out:
# 'UT90'

# %%
ts.uuid
# Out:
# '6a0af14426c63513ae3b3256f4148244'

# %%
t.to_xlsx("test.xlsx")

# %%
ts.to_xlsx("testseries.xlsx")

# %%
tp.to_xlsx("testprogram.xlsx")
